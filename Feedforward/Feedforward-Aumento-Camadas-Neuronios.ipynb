# %% [markdown]
# # Reconhecimento de Movimentos Utilizando uma Rede Feedforward (FNN)
# ## Aumento do número de camadas e neurónios

# %%
import pandas as pd

labels = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/activity_labels.txt", sep="\s+", header=None)

labels
# Out:
#    0                   1
# 0  1             WALKING
# 1  2    WALKING_UPSTAIRS
# 2  3  WALKING_DOWNSTAIRS
# 3  4             SITTING
# 4  5            STANDING
# 5  6              LAYING

# %% [markdown]
# ## Preparação dos *Datasets*

# %%
# Carregar os datasets
X_train = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/train/X_train.txt", header=None, sep="\s+")
y_train = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/train/y_train.txt", header=None)

X_test_val = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/test/X_test.txt", sep="\s+", header=None)
y_test_val = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/test/y_test.txt", header=None)

X_test = X_test_val[0:round(0.9*X_test_val.shape[0])]
X_val = X_test_val[round(0.9*X_test_val.shape[0]):]
y_test = y_test_val[0:round(0.9*y_test_val.shape[0])]
y_val = y_test_val[round(0.9*y_test_val.shape[0]):]

X_train.shape, y_train.shape
# Out:
# ((7352, 561), (7352, 1))

# %% [markdown]
# ## Criar o Modelo

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import keras

# Criação do objeto do Modelo
modelo = Sequential()
modelo.add(Dense(736, activation="relu"))
modelo.add(Dense(368, activation="relu"))
modelo.add(Dense(123, activation="relu"))
modelo.add(Dense(31, activation="relu"))
modelo.add(Dense(7, activation="softmax"))

modelo.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy", "precision", "recall", "f1_score"])

y_treino_cat = to_categorical(y_train)
y_teste_cat = to_categorical(y_test)
y_val_cat = to_categorical(y_val)

historico = modelo.fit(X_train, y_treino_cat, epochs=20, batch_size=10, validation_data=(X_val, y_val_cat))
modelo.save("ModeloFNN-Changed.keras")
# Out:
# Epoch 1/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.7454 - f1_score: 0.6356 - loss: 0.1555 - precision: 0.7863 - recall: 0.7088 - val_accuracy: 0.9831 - val_f1_score: 0.8417 - val_loss: 0.0255 - val_precision: 0.9864 - val_recall: 0.9831
# Epoch 2/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9366 - f1_score: 0.8054 - loss: 0.0440 - precision: 0.9377 - recall: 0.9362 - val_accuracy: 0.9525 - val_f1_score: 0.8200 - val_loss: 0.0296 - val_precision: 0.9525 - val_recall: 0.9525
# Epoch 3/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9516 - f1_score: 0.8166 - loss: 0.0369 - precision: 0.9521 - recall: 0.9511 - val_accuracy: 0.9864 - val_f1_score: 0.8408 - val_loss: 0.0118 - val_precision: 0.9864 - val_recall: 0.9864
# Epoch 4/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9602 - f1_score: 0.8239 - loss: 0.0289 - precision: 0.9619 - recall: 0.9594 - val_accuracy: 0.9763 - val_f1_score: 0.8366 - val_loss: 0.0173 - val_precision: 0.9863 - val_recall: 0.9763
# Epoch 5/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9602 - f1_score: 0.8236 - loss: 0.0289 - precision: 0.9607 - recall: 0.9598 - val_accuracy: 0.9831 - val_f1_score: 0.8416 - val_loss: 0.0147 - val_precision: 0.9831 - val_recall: 0.9831
# Epoch 6/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9565 - f1_score: 0.8210 - loss: 0.0351 - precision: 0.9573 - recall: 0.9550 - val_accuracy: 0.9932 - val_f1_score: 0.8490 - val_loss: 0.0063 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 7/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9751 - f1_score: 0.8372 - loss: 0.0206 - precision: 0.9751 - recall: 0.9750 - val_accuracy: 0.9051 - val_f1_score: 0.7843 - val_loss: 0.1003 - val_precision: 0.9082 - val_recall: 0.9051
# Epoch 8/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9685 - f1_score: 0.8313 - loss: 0.0222 - precision: 0.9685 - recall: 0.9684 - val_accuracy: 0.9525 - val_f1_score: 0.8008 - val_loss: 0.0308 - val_precision: 0.9525 - val_recall: 0.9525
# Epoch 9/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9707 - f1_score: 0.8333 - loss: 0.0207 - precision: 0.9711 - recall: 0.9707 - val_accuracy: 0.9864 - val_f1_score: 0.8424 - val_loss: 0.0057 - val_precision: 0.9864 - val_recall: 0.9864
# Epoch 10/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9757 - f1_score: 0.8374 - loss: 0.0199 - precision: 0.9758 - recall: 0.9756 - val_accuracy: 0.9898 - val_f1_score: 0.8448 - val_loss: 0.0123 - val_precision: 0.9898 - val_recall: 0.9898
# Epoch 11/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9718 - f1_score: 0.8324 - loss: 0.0245 - precision: 0.9725 - recall: 0.9713 - val_accuracy: 0.9898 - val_f1_score: 0.8448 - val_loss: 0.0107 - val_precision: 0.9898 - val_recall: 0.9898
# Epoch 12/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.9762 - f1_score: 0.8382 - loss: 0.0185 - precision: 0.9767 - recall: 0.9761 - val_accuracy: 1.0000 - val_f1_score: 0.8571 - val_loss: 0.0036 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 13/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9774 - f1_score: 0.8386 - loss: 0.0166 - precision: 0.9774 - recall: 0.9773 - val_accuracy: 0.9966 - val_f1_score: 0.8547 - val_loss: 0.0064 - val_precision: 0.9966 - val_recall: 0.9966
# Epoch 14/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9770 - f1_score: 0.8378 - loss: 0.0181 - precision: 0.9770 - recall: 0.9763 - val_accuracy: 1.0000 - val_f1_score: 0.8571 - val_loss: 0.0055 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 15/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9841 - f1_score: 0.8443 - loss: 0.0145 - precision: 0.9841 - recall: 0.9837 - val_accuracy: 0.9966 - val_f1_score: 0.8531 - val_loss: 0.0038 - val_precision: 0.9966 - val_recall: 0.9966
# Epoch 16/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9756 - f1_score: 0.8369 - loss: 0.0192 - precision: 0.9761 - recall: 0.9756 - val_accuracy: 1.0000 - val_f1_score: 0.8571 - val_loss: 0.0029 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 17/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.9801 - f1_score: 0.8411 - loss: 0.0160 - precision: 0.9802 - recall: 0.9801 - val_accuracy: 0.9831 - val_f1_score: 0.8399 - val_loss: 0.0108 - val_precision: 0.9864 - val_recall: 0.9831
# Epoch 18/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9743 - f1_score: 0.8362 - loss: 0.0172 - precision: 0.9747 - recall: 0.9743 - val_accuracy: 0.9932 - val_f1_score: 0.8490 - val_loss: 0.0034 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 19/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9788 - f1_score: 0.8393 - loss: 0.0165 - precision: 0.9791 - recall: 0.9788 - val_accuracy: 0.9966 - val_f1_score: 0.8531 - val_loss: 0.0024 - val_precision: 0.9966 - val_recall: 0.9966
# Epoch 20/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9778 - f1_score: 0.8384 - loss: 0.0158 - precision: 0.9781 - recall: 0.9777 - val_accuracy: 1.0000 - val_f1_score: 0.8571 - val_loss: 0.0053 - val_precision: 1.0000 - val_recall: 1.0000

# %% [markdown]
# ## Avaliação da Precisão do Modelo

# %%
_, precisao, precision, recall, f1_score  = modelo.evaluate(X_test, y_teste_cat)
print(f"Precisão do Modelo: {precisao*100} %")
print(f"Precision do Modelo: {precision[-1]*100} %")
print(f"Recall do Modelo: {recall*100} %")
print(f"F1-Score do Modelo: {f1_score*100} %")
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9440 - f1_score: 0.7936 - loss: 0.0602 - precision: 0.9441 - recall: 0.9440
# Precisão do Modelo: 94.2307710647583 %
# Precision do Modelo: 100.0 %
# Recall do Modelo: 94.26631331443787 %
# F1-Score do Modelo: 94.2307710647583 %

# %% [markdown]
# ## Evolução da Precisão ao Longo do Treino

# %%
import matplotlib.pyplot as plt

plt.plot(historico.history["accuracy"])
plt.plot(historico.history["val_accuracy"])
plt.title("Evolução da Precisão/Validação")
plt.ylabel("Precisão")
plt.xlabel("Época")
plt.legend(["Precisão", "Validação"])
plt.grid()
plt.savefig("Evolução Precisão Validação FNN-Changed", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Matriz de Confusão

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Saídas previstas
y_previsto = modelo.predict(X_test)
y_previsto = [np.argmax(y) for y in y_previsto]

# Saídas Reais
y_real = [np.argmax(y) for y in y_teste_cat]

# Criação da matriz de confusão
cm = confusion_matrix(y_real, y_previsto)
display = ConfusionMatrixDisplay(cm, display_labels=labels[1])

# Mostrar a matriz de confusão
display.plot(xticks_rotation="vertical")
display.figure_.savefig("Matriz de Confusão FNN-Changed", bbox_inches="tight")
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
