# %% [markdown]
# # Reconhecimento de Movimentos Utilizando uma Rede Feedforward (FNN)

# %%
import pandas as pd

labels = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/activity_labels.txt", sep="\s+", header=None)

labels
# Out:
#    0                   1
# 0  1             WALKING
# 1  2    WALKING_UPSTAIRS
# 2  3  WALKING_DOWNSTAIRS
# 3  4             SITTING
# 4  5            STANDING
# 5  6              LAYING

# %% [markdown]
# ## Preparação dos *Datasets*

# %%
# Carregar os datasets
X_train = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/train/X_train.txt", header=None, sep="\s+")
y_train = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/train/y_train.txt", header=None)

X_test_val = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/test/X_test.txt", sep="\s+", header=None)
y_test_val = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/test/y_test.txt", header=None)

X_test = X_test_val[0:round(0.9*X_test_val.shape[0])]
X_val = X_test_val[round(0.9*X_test_val.shape[0]):]
y_test = y_test_val[0:round(0.9*y_test_val.shape[0])]
y_val = y_test_val[round(0.9*y_test_val.shape[0]):]

X_train.shape, y_train.shape
# Out:
# ((7352, 561), (7352, 1))

# %% [markdown]
# ## Criar o Modelo

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import keras

# Criação do objeto do Modelo
modelo = Sequential()
modelo.add(Dense(576, activation="relu"))
modelo.add(Dense(9, activation="relu"))
modelo.add(Dense(7, activation="softmax"))

modelo.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', 'Precision', 'Recall'])

y_treino_cat = to_categorical(y_train)
y_teste_cat = to_categorical(y_test)
y_val_cat = to_categorical(y_val)

historico = modelo.fit(X_train, y_treino_cat, epochs=20, batch_size=10, validation_data=(X_val, y_val_cat))
modelo.save("ModeloFNN.keras")
# Out:
# Epoch 1/20
# 736/736 [==============================] - 3s 3ms/step - loss: 0.1218 - accuracy: 0.8260 - precision: 0.8651 - recall: 0.8074 - val_loss: 0.0276 - val_accuracy: 0.9932 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 2/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0438 - accuracy: 0.9471 - precision: 0.9477 - recall: 0.9468 - val_loss: 0.0156 - val_accuracy: 0.9966 - val_precision: 0.9966 - val_recall: 0.9966
# Epoch 3/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0336 - accuracy: 0.9563 - precision: 0.9566 - recall: 0.9563 - val_loss: 0.0092 - val_accuracy: 0.9932 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 4/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0245 - accuracy: 0.9695 - precision: 0.9695 - recall: 0.9695 - val_loss: 0.0361 - val_accuracy: 0.9288 - val_precision: 0.9288 - val_recall: 0.9288
# Epoch 5/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0248 - accuracy: 0.9676 - precision: 0.9676 - recall: 0.9676 - val_loss: 0.0071 - val_accuracy: 0.9966 - val_precision: 0.9966 - val_recall: 0.9966
# Epoch 6/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0201 - accuracy: 0.9728 - precision: 0.9728 - recall: 0.9728 - val_loss: 0.0115 - val_accuracy: 0.9898 - val_precision: 0.9898 - val_recall: 0.9898
# Epoch 7/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0199 - accuracy: 0.9723 - precision: 0.9723 - recall: 0.9723 - val_loss: 0.0255 - val_accuracy: 0.9729 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 8/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0183 - accuracy: 0.9747 - precision: 0.9748 - recall: 0.9747 - val_loss: 0.0248 - val_accuracy: 0.9729 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 9/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0170 - accuracy: 0.9780 - precision: 0.9780 - recall: 0.9778 - val_loss: 0.0231 - val_accuracy: 0.9729 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 10/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0168 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - val_loss: 0.0422 - val_accuracy: 0.9458 - val_precision: 0.9490 - val_recall: 0.9458
# Epoch 11/20
# 736/736 [==============================] - 2s 3ms/step - loss: 0.0191 - accuracy: 0.9731 - precision: 0.9731 - recall: 0.9731 - val_loss: 0.0055 - val_accuracy: 0.9932 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 12/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0149 - accuracy: 0.9799 - precision: 0.9799 - recall: 0.9799 - val_loss: 0.0075 - val_accuracy: 0.9898 - val_precision: 0.9898 - val_recall: 0.9898
# Epoch 13/20
# 736/736 [==============================] - 2s 3ms/step - loss: 0.0154 - accuracy: 0.9791 - precision: 0.9791 - recall: 0.9791 - val_loss: 0.0097 - val_accuracy: 0.9864 - val_precision: 0.9864 - val_recall: 0.9864
# Epoch 14/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0156 - accuracy: 0.9807 - precision: 0.9810 - recall: 0.9807 - val_loss: 0.0049 - val_accuracy: 0.9932 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 15/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0142 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - val_loss: 0.0023 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 16/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0138 - accuracy: 0.9814 - precision: 0.9814 - recall: 0.9814 - val_loss: 0.0026 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 17/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0142 - accuracy: 0.9808 - precision: 0.9808 - recall: 0.9808 - val_loss: 0.0055 - val_accuracy: 0.9932 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 18/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0136 - accuracy: 0.9816 - precision: 0.9816 - recall: 0.9816 - val_loss: 0.0020 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 19/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0118 - accuracy: 0.9837 - precision: 0.9837 - recall: 0.9837 - val_loss: 0.0090 - val_accuracy: 0.9864 - val_precision: 0.9864 - val_recall: 0.9864
# Epoch 20/20
# 736/736 [==============================] - 2s 2ms/step - loss: 0.0137 - accuracy: 0.9827 - precision: 0.9827 - recall: 0.9827 - val_loss: 0.0142 - val_accuracy: 0.9831 - val_precision: 0.9831 - val_recall: 0.9831

# %% [markdown]
# ## Avaliação da Precisão do Modelo

# %%
_, precisao, precision, recall  = modelo.evaluate(X_test, y_teste_cat)
f1_score = (2 * precision * recall) / (precision + recall)
print(f"Precisão do Modelo: {precisao*100} %")
print(f"Precision do Modelo: {precision*100} %")
print(f"Recall do Modelo: {recall*100} %")
print(f"F1-Score do Modelo: {f1_score*100} %")
# Out:
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0571 - accuracy: 0.9423 - precision: 0.9423 - recall: 0.9423
# Precisão do Modelo: 94.2307710647583 %
# Precision do Modelo: 94.2307710647583 %
# Recall do Modelo: 94.2307710647583 %
# F1-Score do Modelo: 94.2307710647583 %

# %% [markdown]
# ## Evolução da Precisão ao Longo do Treino

# %%
import matplotlib.pyplot as plt
import os

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

plt.plot(historico.history["accuracy"])
plt.plot(historico.history["val_accuracy"])
plt.title("Evolução da Precisão/Validação")
plt.ylabel("Precisão")
plt.xlabel("Época")
plt.legend(["Precisão", "Validação"])
plt.grid()
plt.savefig("Evolução Precisão Validação FNN", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Matriz de Confusão

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Saídas previstas
y_previsto = modelo.predict(X_test)
y_previsto = [np.argmax(y) for y in y_previsto]

# Saídas Reais
y_real = [np.argmax(y) for y in y_teste_cat]

# Criação da matriz de confusão
cm = confusion_matrix(y_real, y_previsto)
display = ConfusionMatrixDisplay(cm, display_labels=labels[1])

# Mostrar a matriz de confusão
display.plot(xticks_rotation="vertical")
display.figure_.savefig("Matriz de Confusão FNN", bbox_inches="tight")
# Out:
# 83/83 [==============================] - 0s 1ms/step
