# %% [markdown]
# # Reconhecimento de Movimentos Utilizando uma Rede Feedforward (FNN)

# %%
import pandas as pd

labels = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/activity_labels.txt", sep="\s+", header=None)

labels
# Out:
#    0                   1
# 0  1             WALKING
# 1  2    WALKING_UPSTAIRS
# 2  3  WALKING_DOWNSTAIRS
# 3  4             SITTING
# 4  5            STANDING
# 5  6              LAYING

# %% [markdown]
# ## Preparação dos *Datasets*

# %%
# Carregar os datasets
X_train = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/train/X_train.txt", header=None, sep="\s+")
y_train = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/train/y_train.txt", header=None)

X_test_val = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/test/X_test.txt", sep="\s+", header=None)
y_test_val = pd.read_csv("../Dataset/UCI HAR Dataset/UCI HAR Dataset/test/y_test.txt", header=None)

X_test = X_test_val[0:round(0.9*X_test_val.shape[0])]
X_val = X_test_val[round(0.9*X_test_val.shape[0]):]
y_test = y_test_val[0:round(0.9*y_test_val.shape[0])]
y_val = y_test_val[round(0.9*y_test_val.shape[0]):]

X_train.shape, y_train.shape
# Out:
# ((7352, 561), (7352, 1))

# %% [markdown]
# ## Criar o Modelo

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import keras

# Criação do objeto do Modelo
modelo = Sequential()
modelo.add(Dense(576, activation="relu"))
modelo.add(Dense(9, activation="relu"))
modelo.add(Dense(7, activation="softmax"))

modelo.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', 'precision', 'recall', 'f1_score'])

y_treino_cat = to_categorical(y_train)
y_teste_cat = to_categorical(y_test)
y_val_cat = to_categorical(y_val)

historico = modelo.fit(X_train, y_treino_cat, epochs=20, batch_size=10, validation_data=(X_val, y_val_cat))
modelo.save("ModeloFNN.keras")
# Out:
# Epoch 1/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.1923 - f1_score: 0.1268 - loss: 0.5807 - precision: 0.4612 - recall: 0.0326 - val_accuracy: 0.2000 - val_f1_score: 0.0547 - val_loss: 0.3814 - val_precision: 0.9153 - val_recall: 0.1831
# Epoch 2/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.2701 - f1_score: 0.1752 - loss: 0.3949 - precision: 0.6903 - recall: 0.1095 - val_accuracy: 0.4814 - val_f1_score: 0.3011 - val_loss: 0.3226 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.5992 - f1_score: 0.4532 - loss: 0.3140 - precision: 0.6022 - recall: 0.1834 - val_accuracy: 0.8169 - val_f1_score: 0.6865 - val_loss: 0.2366 - val_precision: 0.7923 - val_recall: 0.5559
# Epoch 4/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8930 - f1_score: 0.7635 - loss: 0.2080 - precision: 0.8982 - recall: 0.6082 - val_accuracy: 0.9390 - val_f1_score: 0.8051 - val_loss: 0.1718 - val_precision: 0.9490 - val_recall: 0.8203
# Epoch 5/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9360 - f1_score: 0.8023 - loss: 0.1662 - precision: 0.9521 - recall: 0.8219 - val_accuracy: 0.8542 - val_f1_score: 0.7213 - val_loss: 0.1811 - val_precision: 0.8627 - val_recall: 0.8305
# Epoch 6/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9448 - f1_score: 0.8104 - loss: 0.1430 - precision: 0.9554 - recall: 0.9202 - val_accuracy: 0.9390 - val_f1_score: 0.8079 - val_loss: 0.1443 - val_precision: 0.9386 - val_recall: 0.9322
# Epoch 7/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9543 - f1_score: 0.8179 - loss: 0.1208 - precision: 0.9624 - recall: 0.9427 - val_accuracy: 0.9729 - val_f1_score: 0.8339 - val_loss: 0.1021 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 8/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9680 - f1_score: 0.8299 - loss: 0.1041 - precision: 0.9712 - recall: 0.9616 - val_accuracy: 0.9695 - val_f1_score: 0.8283 - val_loss: 0.1025 - val_precision: 0.9726 - val_recall: 0.9627
# Epoch 9/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9656 - f1_score: 0.8288 - loss: 0.0968 - precision: 0.9705 - recall: 0.9609 - val_accuracy: 0.9763 - val_f1_score: 0.8366 - val_loss: 0.0851 - val_precision: 0.9763 - val_recall: 0.9763
# Epoch 10/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9701 - f1_score: 0.8326 - loss: 0.0760 - precision: 0.9730 - recall: 0.9677 - val_accuracy: 0.9153 - val_f1_score: 0.7948 - val_loss: 0.0948 - val_precision: 0.9184 - val_recall: 0.9153
# Epoch 11/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9697 - f1_score: 0.8315 - loss: 0.0551 - precision: 0.9698 - recall: 0.9697 - val_accuracy: 0.9898 - val_f1_score: 0.8465 - val_loss: 0.0450 - val_precision: 0.9898 - val_recall: 0.9898
# Epoch 12/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9724 - f1_score: 0.8349 - loss: 0.0447 - precision: 0.9725 - recall: 0.9723 - val_accuracy: 0.9932 - val_f1_score: 0.8506 - val_loss: 0.0363 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 13/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9805 - f1_score: 0.8413 - loss: 0.0369 - precision: 0.9805 - recall: 0.9805 - val_accuracy: 0.9864 - val_f1_score: 0.8441 - val_loss: 0.0342 - val_precision: 0.9864 - val_recall: 0.9864
# Epoch 14/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9747 - f1_score: 0.8361 - loss: 0.0370 - precision: 0.9747 - recall: 0.9747 - val_accuracy: 0.9932 - val_f1_score: 0.8506 - val_loss: 0.0234 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 15/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9799 - f1_score: 0.8402 - loss: 0.0303 - precision: 0.9799 - recall: 0.9799 - val_accuracy: 0.9932 - val_f1_score: 0.8505 - val_loss: 0.0275 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 16/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9793 - f1_score: 0.8404 - loss: 0.0269 - precision: 0.9793 - recall: 0.9793 - val_accuracy: 0.9966 - val_f1_score: 0.8531 - val_loss: 0.0186 - val_precision: 0.9966 - val_recall: 0.9966
# Epoch 17/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9825 - f1_score: 0.8424 - loss: 0.0240 - precision: 0.9825 - recall: 0.9825 - val_accuracy: 0.9966 - val_f1_score: 0.8531 - val_loss: 0.0213 - val_precision: 0.9966 - val_recall: 0.9966
# Epoch 18/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9806 - f1_score: 0.8416 - loss: 0.0255 - precision: 0.9806 - recall: 0.9806 - val_accuracy: 0.9932 - val_f1_score: 0.8490 - val_loss: 0.0202 - val_precision: 0.9932 - val_recall: 0.9932
# Epoch 19/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9753 - f1_score: 0.8370 - loss: 0.0269 - precision: 0.9753 - recall: 0.9753 - val_accuracy: 0.9898 - val_f1_score: 0.8465 - val_loss: 0.0149 - val_precision: 0.9898 - val_recall: 0.9898
# Epoch 20/20
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9825 - f1_score: 0.8428 - loss: 0.0209 - precision: 0.9825 - recall: 0.9825 - val_accuracy: 0.9932 - val_f1_score: 0.8521 - val_loss: 0.0203 - val_precision: 0.9932 - val_recall: 0.9932

# %% [markdown]
# ## Avaliação da Precisão do Modelo

# %%
_, precisao, precision, recall, f1_score  = modelo.evaluate(X_test, y_teste_cat)
print(f"Precisão do Modelo: {precisao*100} %")
print(f"Precision do Modelo: {precision[-1]*100} %")
print(f"Recall do Modelo: {recall*100} %")
print(f"F1-Score do Modelo: {f1_score*100} %")
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9298 - f1_score: 0.7809 - loss: 0.1047 - precision: 0.9298 - recall: 0.9292
# Precisão do Modelo: 91.32729768753052 %
# Precision do Modelo: 97.24575805664062 %
# Recall do Modelo: 91.32403135299683 %
# F1-Score do Modelo: 91.2895917892456 %

# %% [markdown]
# ## Evolução da Precisão ao Longo do Treino

# %%
import matplotlib.pyplot as plt

plt.plot(historico.history["accuracy"])
plt.plot(historico.history["val_accuracy"])
plt.title("Evolução da Precisão/Validação")
plt.ylabel("Precisão")
plt.xlabel("Época")
plt.legend(["Precisão", "Validação"])
plt.grid()
plt.savefig("Evolução Precisão Validação FNN", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Matriz de Confusão

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Saídas previstas
y_previsto = modelo.predict(X_test)
y_previsto = [np.argmax(y) for y in y_previsto]

# Saídas Reais
y_real = [np.argmax(y) for y in y_teste_cat]

# Criação da matriz de confusão
cm = confusion_matrix(y_real, y_previsto)
display = ConfusionMatrixDisplay(cm, display_labels=labels[1])

# Mostrar a matriz de confusão
display.plot(xticks_rotation="vertical")
display.figure_.savefig("Matriz de Confusão FNN", bbox_inches="tight")
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
